# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df.nunique()
# Out:
# id                      381109
# Gender                       2
# Age                         66
# Driving_License              2
# Region_Code                 53
# Previously_Insured           2
# Vehicle_Age                  3
# Vehicle_Damage               2
# Annual_Premium           48838
# Policy_Sales_Channel       155
# Vintage                    290
# Response                     2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24405.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39400.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response
# count  381109.000000  381109.000000
# mean      154.347397       0.122563
# std        83.671304       0.327936
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
df.describe(include = 'object') # columns with objects
# Out:
#         Gender Vehicle_Age Vehicle_Damage
# count   381109      381109         381109
# unique       2           3              2
# top       Male    1-2 Year            Yes
# freq    206089      200316         192413

# %% [markdown]
# # Data Visualization

# %%
df.Gender.value_counts().plot(kind='bar')

df['Gender'].value_counts()
# Out:
# Male      206089
# Female    175020
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Driving_License',data=df)

df['Driving_License'].value_counts()
# Out:
# 1    380297
# 0       812
# Name: Driving_License, dtype: int64

# %%
sns.countplot(x='Previously_Insured', data=df)

df['Previously_Insured'].value_counts()
# Out:
# 0    206481
# 1    174628
# Name: Previously_Insured, dtype: int64

# %%
df.Vehicle_Age.value_counts().plot(kind='pie',colors=['green','orange','yellow'],autopct='%.2f')
df.Vehicle_Age.value_counts()
# Out:
# 1-2 Year     200316
# < 1 Year     164786
# > 2 Years     16007
# Name: Vehicle_Age, dtype: int64

# %%
sns.countplot(x=df.Vehicle_Damage)

df['Vehicle_Damage'].value_counts()
# Out:
# Yes    192413
# No     188696
# Name: Vehicle_Damage, dtype: int64

# %%
sns.countplot(x=df.Response)

df['Response'].value_counts()
# Out:
# 0    334399
# 1     46710
# Name: Response, dtype: int64

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
sns.distplot(df['Age'],bins=5)
# Out:
# <ipython-input-28-382f1ee77f10>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],bins=5)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Annual_Premium'])
# Out:
# <Axes: >

# %%
sns.distplot(df['Annual_Premium'],bins=30)
# Out:
# <ipython-input-30-631f2b88cbe8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Annual_Premium'],bins=30)
# <Axes: xlabel='Annual_Premium', ylabel='Density'>

# %%
sns.boxplot(df['Vintage'])
# Out:
# <Axes: >

# %% [markdown]
# #Data visualization - Relationshio between variables and interaction terms

# %%
sns.barplot(x='Response', y='Age',data=df)
# Out:
# <Axes: xlabel='Response', ylabel='Age'>

# %%
sns.barplot(x='Response', y='Annual_Premium',data=df)
# Out:
# <Axes: xlabel='Response', ylabel='Annual_Premium'>

# %%
sns.barplot(x='Response', y='Vintage',data=df)
# Out:
# <Axes: xlabel='Response', ylabel='Vintage'>

# %%
sns.catplot(x = 'Response', y = 'Age', data = df, kind = 'box')

# %%
sns.catplot(x = 'Response', y = 'Annual_Premium', data = df, kind = 'box')

# %%
sns.catplot(x = 'Response', y = 'Vintage', data = df, kind = 'box')

# %%
sns.barplot(x='Response', y='Annual_Premium', hue = 'Driving_License', data=df)
# Out:
# <Axes: xlabel='Response', ylabel='Annual_Premium'>

# %%
sns.countplot(x='Vehicle_Damage', hue = 'Response', data =df)
# Out:
# <Axes: xlabel='Vehicle_Damage', ylabel='count'>

# %%
sns.countplot(x='Previously_Insured', hue = 'Response', data =df)
# Out:
# <Axes: xlabel='Previously_Insured', ylabel='count'>

# %%
sns.countplot(x='Vehicle_Age', hue = 'Response', data =df)
# Out:
# <Axes: xlabel='Vehicle_Age', ylabel='count'>

# %% [markdown]
# # Encoding non numeric columns to understand correlations

# %%
df_corr = df.copy()

# %%
df_corr.Gender.replace({'Male':1, 'Female':2}, inplace = True)

# %%
df_corr.Vehicle_Damage.replace({'Yes':1, 'No':0}, inplace = True)

# %%
df_corr.Vehicle_Age.replace({'< 1 Year':1, '1-2 Year':2, '> 2 Years':3}, inplace = True)

# %%
df_corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  int64
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  int64
#  7   Vehicle_Damage        381109 non-null  int64
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(9)
# memory usage: 34.9 MB

# %%
df_corr.corr()['Response']
# Out:
# id                     -0.001368
# Gender                 -0.052440
# Age                     0.111147
# Driving_License         0.010155
# Region_Code             0.010570
# Previously_Insured     -0.341170
# Vehicle_Age             0.221874
# Vehicle_Damage          0.354400
# Annual_Premium          0.022575
# Policy_Sales_Channel   -0.139042
# Vintage                -0.001050
# Response                1.000000
# Name: Response, dtype: float64

# %%
import plotly.express as px

px.bar(df_corr.corr()['Response'], width = 1100, height = 700)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ed3a456f-7897-4003-9b99-e397eb63c785" class="plotly-graph-div" style="height:700px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed3a456f-7897-4003-9b99-e397eb63c785")) {                    Plotly.newPlot(                        "ed3a456f-7897-4003-9b99-e397eb63c785",                        [{"alignmentgroup":"True","hovertemplate":"variable=Response<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Response","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Response","offsetgroup":"Response","orientation":"v","showlegend":true,"textposition":"auto","x":["id","Gender","Age","Driving_License","Region_Code","Previously_Insured","Vehicle_Age","Vehicle_Damage","Annual_Premium","Policy_Sales_Channel","Vintage","Response"],"xaxis":"x","y":[-0.0013681501902191634,-0.05243991377134181,0.11114689471250443,0.01015517459407361,0.010569855615223027,-0.34117046261352446,0.2218739872179834,0.35439954387975825,0.022574695542559607,-0.1390415008291577,-0.0010503720019900001,1.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"s ...

# %% [markdown]
# # Featuring Engineering

# %%
df['Gender'] = df.Gender.astype('category')

# %%
df['Driving_License'] = df.Driving_License.astype('category')

# %%
df['Region_Code'] = df.Region_Code.astype('category')

# %%
df['Previously_Insured'] = df.Previously_Insured.astype('category')

# %%
df['Vehicle_Age'] = df.Vehicle_Age.astype('category')

# %%
df['Vehicle_Damage'] = df.Vehicle_Damage.astype('category')

# %%
df['Policy_Sales_Channel'] = df.Policy_Sales_Channel.astype('category')

# %%
df['Response'] = df.Response.astype('bool')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  category
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  category
#  4   Region_Code           381109 non-null  category
#  5   Previously_Insured    381109 non-null  category
#  6   Vehicle_Age           381109 non-null  category
#  7   Vehicle_Damage        381109 non-null  category
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  category
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  bool
# dtypes: bool(1), category(7), float64(1), int64(3)
# memory usage: 14.9 MB

# %%
df = df.drop(columns = 'id')

# %%
df.head()
# Out:
#    Gender  Age Driving_License Region_Code Previously_Insured Vehicle_Age  \
# 0    Male   44               1        28.0                  0   > 2 Years
# 1    Male   76               1         3.0                  0    1-2 Year
# 2    Male   47               1        28.0                  0   > 2 Years
# 3    Male   21               1        11.0                  1    < 1 Year
# 4  Female   29               1        41.0                  1    < 1 Year
#
#   Vehicle_Damage  Annual_Premium Policy_Sales_Channel  Vintage  Response
# 0            Yes         40454.0                 26.0      217      True
# 1             No         33536.0                 26.0      183     False
# 2            Yes         38294.0                 26.0       27      True
# 3             No         28619.0                152.0      203     False
# 4             No         27496.0                152.0       39     False

# %%
X = df.copy()
X.drop('Response',axis=1,inplace=True)
X
# Out:
#         Gender  Age Driving_License Region_Code Previously_Insured  \
# 0         Male   44               1        28.0                  0
# 1         Male   76               1         3.0                  0
# 2         Male   47               1        28.0                  0
# 3         Male   21               1        11.0                  1
# 4       Female   29               1        41.0                  1
# ...        ...  ...             ...         ...                ...
# 381104    Male   74               1        26.0                  1
# 381105    Male   30               1        37.0                  1
# 381106    Male   21               1        30.0                  1
# 381107  Female   68               1        14.0                  0
# 381108    Male   46               1        29.0                  0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium Policy_Sales_Channel  \
# 0        > 2 Years            Yes         40454.0                 26.0
# 1         1-2 Year             No         33536.0                 26.0
# 2        > 2 Years            Yes         38294.0                 26.0
# 3         < 1 Year             No         28619.0                152.0
# 4         < 1 Year             No         27496.0                152.0
# ...            ...            ...             ...                  ...
# 381104    1-2 Year             No         30170.0                 26.0
# 381105    < 1 Year             No         40016.0                152.0
# 381106    < 1 Year             No         35118.0                160.0
# 381107   > 2 Years            Yes         44617.0                124.0
# 381108    1-2 Year             No         41777.0                 26.0
#
#         Vintage
# 0           217
# 1           183
# 2            27
# 3           203
# 4            39
# ...         ...
# 381104       88
# 381105      131
# 381106      161
# 381107       74
# 381108      237
#
# [381109 rows x 10 columns]

# %%
y = df['Response']
y
# Out:
# 0          True
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 381104    False
# 381105    False
# 381106    False
# 381107    False
# 381108    False
# Name: Response, Length: 381109, dtype: bool

# %%
dum = pd.get_dummies(X[['Gender', 'Driving_License', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Policy_Sales_Channel']])

# %%
X.drop(columns= ['Gender', 'Driving_License', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Policy_Sales_Channel'], axis = 1 , inplace = True)

# %%
X = pd.concat([X, dum], axis = 1)
X.shape
# Out:
# (381109, 222)

# %% [markdown]
# #Random sampling - Train and test data sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)
print(X_train.shape, X_test.shape)
# Out:
# (304887, 222) (76222, 222)

# %% [markdown]
# # Logistic Regression with Random Sampling

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=100.0, random_state=0)
model_lr = lr.fit(X_train, y_train)

# %%
y_pred_lr = model_lr.predict(X_test)
from sklearn.metrics import accuracy_score
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_lr))
# Out:
# Accuracy: 0.87

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# [[66487   359]
#  [ 9227   149]]

# %%
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt


# predict probabilities on test set
y_pred_lr_proba = model_lr.predict_proba(X_test)[:,1]

# calculate AUC
auc_lr = roc_auc_score(y_test, y_pred_lr_proba)
print('AUC:', auc_lr)

# plot ROC curve using RocCurveDisplay
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_pred_lr_proba)
roc_display_lr = RocCurveDisplay(fpr=fpr_lr, tpr=tpr_lr, roc_auc=auc_lr, estimator_name='Logistic Regression')
roc_display_lr.plot()
plt.show()
# Out:
# AUC: 0.8358910602897147

# %%
def plot_lift_curve(y_test, y_pred, step=0.01):

    #Define an auxiliar dataframe to plot the curve
    aux_lift = pd.DataFrame()
    #Create a real and predicted column for our new DataFrame and assign values
    aux_lift['real'] = y_test
    aux_lift['predicted'] = y_pred
    #Order the values for the predicted probability column:
    aux_lift.sort_values('predicted',ascending=False,inplace=True)

    #Create the values that will go into the X axis of our plot
    x_val = np.arange(step,1+step,step)
    #Calculate the ratio of ones in our data
    ratio_ones = aux_lift['real'].sum() / len(aux_lift)
    #Create an empty vector with the values that will go on the Y axis our our plot
    y_val = []

    #Calculate for each x value its correspondent y value
    for x in x_val:
        num_data = int(np.ceil(x*len(aux_lift))) #The ceil function returns the closest integer bigger than our number
        data_here = aux_lift.iloc[:num_data,:]   # ie. np.ceil(1.4) = 2
        ratio_ones_here = data_here['real'].sum()/len(data_here)
        y_val.append(ratio_ones_here / ratio_ones)

   #Plot the figure
    fig, axis = plt.subplots()
    fig.figsize = (40,40)
    axis.plot(x_val, y_val, 'g-', linewidth = 3, markersize = 5)
    axis.plot(x_val, np.ones(len(x_val)), 'k-')
    axis.set_xlabel('Proportion of sample')
    axis.set_ylabel('Lift')
    plt.title('Lift Curve')
    plt.show()

# %%
plot_lift_curve(y_test, y_pred_lr_proba, step=0.01)

# %% [markdown]
# #SMOTE Sampling

# %%
from imblearn.over_sampling import SMOTE

X_train_resampled, y_train_resampled = SMOTE(random_state = 0).fit_resample(X_train, y_train)

# %%
X_train_resampled.shape
# Out:
# (535106, 222)

# %% [markdown]
# # Logistic regression with SMOTE oversampling

# %%
model_lr_SMOTE = lr.fit(X_train_resampled, y_train_resampled)

# %%
y_pred_lr_SMOTE = model_lr_SMOTE.predict(X_test)
from sklearn.metrics import accuracy_score
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_lr_SMOTE))
# Out:
# Accuracy: 0.74

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred_lr_SMOTE))
# Out:
# [[48670 18176]
#  [ 1980  7396]]

# %%
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt


# predict probabilities on test set
y_pred_lr_SMOTE_proba = model_lr_SMOTE.predict_proba(X_test)[:,1]

# calculate AUC
auc_lr_SMOTE = roc_auc_score(y_test, y_pred_lr_SMOTE_proba)
print('AUC:', auc_lr_SMOTE)

# plot ROC curve using RocCurveDisplay
fpr_lr_SMOTE, tpr_lr_SMOTE, thresholds_lr_SMOTE = roc_curve(y_test, y_pred_lr_SMOTE_proba)
roc_display_lr_SMOTE = RocCurveDisplay(fpr=fpr_lr_SMOTE, tpr=tpr_lr_SMOTE, roc_auc=auc_lr_SMOTE, estimator_name='Logistic Regression with SMOTE')
roc_display_lr_SMOTE.plot()
plt.show()
# Out:
# AUC: 0.831954738798281

# %%
plot_lift_curve(y_test, y_pred_lr_SMOTE_proba)

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=0)
model_dt = dt.fit(X_train, y_train)

# %%
y_pred_dt = model_dt.predict(X_test)
from sklearn.metrics import accuracy_score
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_dt))
# Out:
# Accuracy: 0.83

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# [[60132  6714]
#  [ 6550  2826]]

# %%
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt


# predict probabilities on test set
y_pred_dt_proba = model_dt.predict_proba(X_test)[:,1]

# calculate AUC
auc_dt = roc_auc_score(y_test, y_pred_dt_proba)
print('AUC:', auc_dt)

# plot ROC curve using RocCurveDisplay
fpr_dt, tpr_dt, thresholds_dt = roc_curve(y_test, y_pred_dt_proba)
roc_display_dt = RocCurveDisplay(fpr=fpr_dt, tpr=tpr_dt, roc_auc=auc_dt, estimator_name='Decision Tree')
roc_display_dt.plot()
plt.show()
# Out:
# AUC: 0.600617479977155

# %%
plot_lift_curve(y_test, y_pred_dt_proba)

# %% [markdown]
# # Decision Tree with SMOTE

# %%
model_dt_SMOTE = dt.fit(X_train_resampled, y_train_resampled)

# %%
y_pred_dt_SMOTE = model_dt_SMOTE.predict(X_test)
from sklearn.metrics import accuracy_score
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_dt_SMOTE))
# Out:
# Accuracy: 0.82

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred_dt_SMOTE))
# Out:
# [[59699  7147]
#  [ 6377  2999]]

# %%
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt


# predict probabilities on test set
y_pred_dt_SMOTE_proba = model_dt_SMOTE.predict_proba(X_test)[:,1]

# calculate AUC
auc_dt_SMOTE = roc_auc_score(y_test, y_pred_dt_SMOTE_proba)
print('AUC:', auc_dt_SMOTE)

# plot ROC curve using RocCurveDisplay
fpr_dt_SMOTE, tpr_dt_SMOTE, thresholds_dt_SMOTE = roc_curve(y_test, y_pred_dt_SMOTE_proba)
roc_display_dt_SMOTE = RocCurveDisplay(fpr=fpr_dt_SMOTE, tpr=tpr_dt_SMOTE, roc_auc=auc_dt_SMOTE, estimator_name='Decision Tree with SMOTE')
roc_display_dt_SMOTE.plot()
plt.show()
# Out:
# AUC: 0.6064931005390722

# %%
plot_lift_curve(y_test, y_pred_dt_SMOTE_proba)

# %%
df
# Out:
#         Gender  Age Driving_License Region_Code Previously_Insured  \
# 0         Male   44               1        28.0                  0
# 1         Male   76               1         3.0                  0
# 2         Male   47               1        28.0                  0
# 3         Male   21               1        11.0                  1
# 4       Female   29               1        41.0                  1
# ...        ...  ...             ...         ...                ...
# 381104    Male   74               1        26.0                  1
# 381105    Male   30               1        37.0                  1
# 381106    Male   21               1        30.0                  1
# 381107  Female   68               1        14.0                  0
# 381108    Male   46               1        29.0                  0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium Policy_Sales_Channel  \
# 0        > 2 Years            Yes         40454.0                 26.0
# 1         1-2 Year             No         33536.0                 26.0
# 2        > 2 Years            Yes         38294.0                 26.0
# 3         < 1 Year             No         28619.0                152.0
# 4         < 1 Year             No         27496.0                152.0
# ...            ...            ...             ...                  ...
# 381104    1-2 Year             No         30170.0                 26.0
# 381105    < 1 Year             No         40016.0                152.0
# 381106    < 1 Year             No         35118.0                160.0
# 381107   > 2 Years            Yes         44617.0                124.0
# 381108    1-2 Year             No         41777.0                 26.0
#
#         Vintage  Response
# 0           217      True
# 1           183     False
# 2            27      True
# 3           203     False
# 4            39     False
# ...         ...       ...
# 381104       88     False
# 381105      131     False
# 381106      161     False
# 381107       74     False
# 381108      237     False
#
# [381109 rows x 11 columns]

# %%
sns.countplot(x='Policy_Sales_Channel', hue = 'Response', data=df)
# Out:
# <Axes: xlabel='Policy_Sales_Channel', ylabel='count'>

# %% [markdown]
# # Perceptron

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40, eta0=0.1, random_state=0)
ppn.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.1, max_iter=40)

# %%
y_pred_p = ppn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_p))
# Out:
# Accuracy: 0.88

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_p))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.88      1.00      0.93     66846
#         True       0.00      0.00      0.00      9376
#
#     accuracy                           0.88     76222
#    macro avg       0.44      0.50      0.47     76222
# weighted avg       0.77      0.88      0.82     76222
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
# Predict probabilities on Test Set
y_pred_p_proba = ppn.decision_function(X_test)

# Calculate the AUC score
auc_p_score = roc_auc_score(y_true=y_test, y_score=y_pred_p_proba)
print("AUC score:", auc_p_score)

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_p_proba)
roc_p_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc_p_score, estimator_name='Perceptron')
roc_p_display.plot()
plt.show()
# Out:
# AUC score: 0.47509053860771516

# %% [markdown]
# # Perceptron with SMOTE

# %%
ppn_smote = Perceptron(max_iter=40, eta0=0.1, random_state=0)
ppn_smote.fit(X_train_resampled, y_train_resampled)
# Out:
# Perceptron(eta0=0.1, max_iter=40)

# %%
y_pred_p_smote = ppn_smote.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_p_smote))
# Out:
# Accuracy: 0.12

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_p_smote))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.00      0.00     66846
#         True       0.12      1.00      0.22      9376
#
#     accuracy                           0.12     76222
#    macro avg       0.56      0.50      0.11     76222
# weighted avg       0.89      0.12      0.03     76222

# %%
# Predict probabilities on Test Set
y_pred_p_proba_smote = ppn_smote.decision_function(X_test)

# Calculate the AUC score
auc_p_score_smote = roc_auc_score(y_true=y_test, y_score=y_pred_p_proba_smote)
print("AUC score:", auc_p_score_smote)

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_p_proba_smote)
roc_p_display_smote = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc_p_score_smote, estimator_name='Perceptron')
roc_p_display_smote.plot()
plt.show()
# Out:
# AUC score: 0.5386076266596269

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score, accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
rforest = RandomForestClassifier()
rforest = rforest.fit(X_train,y_train)
pred_y = rforest.predict(X_test)
prob_RF = rforest.predict_proba(X_test)[:, 1]

# %%
RF_AUC = roc_auc_score(pred_y,y_test)
rf_accuracy = accuracy_score(y_test,pred_y)
rf_recall = recall_score(y_test,pred_y)
rf_precision = precision_score(y_test,pred_y)
rf_f1 = f1_score(y_test,pred_y)

# %%
print(accuracy_score(pred_y,y_test))
print("ROC_AUC Score:",RF_AUC)
# Out:
# 0.8622182571960851
# ROC_AUC Score: 0.622842088242539

# %%
print(classification_report(pred_y,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      0.89      0.92     72310
#         True       0.15      0.36      0.21      3912
#
#     accuracy                           0.86     76222
#    macro avg       0.56      0.62      0.57     76222
# weighted avg       0.92      0.86      0.89     76222

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds =roc_curve(y_test,prob_RF)

plt.title("ROC Curve")
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')

plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='green')
plt.show()

# %%
cm=confusion_matrix(pred_y,y_test)
print(cm)
sns.heatmap(cm,annot=True,cmap="Paired")
# Out:
# [[64327  7983]
#  [ 2519  1393]]
# <Axes: >

# %% [markdown]
# NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
y_predN = nb.fit(X_train, y_train).predict(X_test)
print("Naive Bayes accuracy: ",nb.score(X_test, y_test))
# Out:
# Naive Bayes accuracy:  0.7208155125816693

# %%
RF_AUC = roc_auc_score(y_predN,y_test)
rf_accuracy = accuracy_score(y_test,y_predN)
rf_recall = recall_score(y_test,y_predN)
rf_precision = precision_score(y_test,y_predN)
rf_f1 = f1_score(y_test,y_predN)
print(accuracy_score(y_predN,y_test))
print("ROC_AUC Score:",RF_AUC)
# Out:
# 0.7208155125816693
# ROC_AUC Score: 0.6263561518519801

# %%
prob_b = nb.predict_proba(X_test)[:, 1]

# %%
print(classification_report(y_predN,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.70      0.97      0.82     48634
#         True       0.84      0.28      0.42     27588
#
#     accuracy                           0.72     76222
#    macro avg       0.77      0.63      0.62     76222
# weighted avg       0.75      0.72      0.67     76222

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds =roc_curve(y_test,prob_b)

plt.title("ROC Curve")
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')

plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='green')
plt.show()

# %%
cm_b=confusion_matrix(y_predN,y_test)
print(cm_b)
sns.heatmap(cm,annot=True,cmap="Paired")
# Out:
# [[47100  1534]
#  [19746  7842]]
# <Axes: >

# %% [markdown]
# FEATURE IMPORTANCE

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_)
f_importances = pd.Series(model.feature_importances_,index=X.columns)
f_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [2.00618751e-01 2.62141787e-01 2.96958420e-01 2.58477735e-03
#  2.62551697e-03 2.64553231e-04 3.00653035e-04 6.67151336e-04
#  4.20007152e-04 7.81190936e-04 1.26925325e-03 7.69054195e-04
#  5.78089486e-04 9.61885798e-04 9.98873890e-04 1.54875231e-03
#  7.11290328e-04 7.77001924e-04 1.17210259e-03 8.62861391e-04
#  8.88289609e-04 9.91902182e-04 1.31294277e-03 5.43835001e-04
#  6.70706070e-04 1.07931415e-03 7.53147837e-04 4.87918764e-04
#  8.75280173e-04 4.32113082e-04 8.39330638e-04 8.76109421e-04
#  4.39462291e-04 5.72895327e-04 5.98976428e-04 4.10031418e-03
#  1.31442315e-03 1.28575550e-03 5.36339405e-04 6.63417980e-04
#  1.24920109e-03 5.18183395e-04 1.07468186e-03 1.07165052e-03
#  8.76185760e-04 8.22876877e-04 1.08381593e-03 6.26597986e-04
#  1.47658808e-03 3.02458008e-04 6.56733955e-04 2.58404982e-04
#  1.07223014e-03 1.57902188e-03 9.43264170e-04 8.43982222e-04
#  5.30398606e-04 9.95926481e-04 2.36408282e-04 2.65676620e-04
#  2.37276076e-02 3.16478730e-02 4.98803620e-03 9.11353925e-03
#  2.49227075e-03 3.20225071e-02 3.61846227e-02 2.21051336e-04
#  1.48164956e-05 4.57755688e-04 4.35013806e-04 1.36227434e-06
#  2.85247309e-04 3.24670640e-04 7.47146355e-05 1.72852139e-04
#  2.96303276e-04 2.64298964e-04 3.61460252e-04 1.76010239e-04
#  1.76613240e-04 1.70714290e-04 3.65394583e-05 7.26877908e-05
#  1.01249994e-04 3.62494038e-05 7.09413549e-05 1.28413473e-04
#  2.17193476e-04 3.07186854e-04 6.24629217e-04 4.87245193e-03
#  1.31171883e-05 1.22103942e-05 4.17576432e-04 4.45105465e-04
#  5.65704179e-04 3.16450988e-05 3.45206830e-06 3.16669260e-06
#  4.98405492e-05 1.06460461e-04 8.69157476e-05 3.53630462e-06
#  1.58753394e-05 2.50422793e-05 0.00000000e+00 1.72762034e-04
#  1.26516619e-05 1.19190674e-04 6.37092250e-05 1.06428329e-05
#  5.58688434e-05 1.93043890e-05 2.44731334e-05 2.80328898e-06
#  8.70841706e-06 2.55297730e-04 6.11324567e-05 9.65319493e-05
#  3.51219495e-04 7.19849879e-05 8.22611892e-06 2.36146429e-05
#  1.32957433e-04 2.17954229e-04 2.11909084e-04 1.21301570e-05
#  1.34031558e-05 4.01648637e-05 4.89130077e-05 1.41478164e-05
#  5.42340026e-06 1.20475306e-05 1.10633131e-05 3.20139254e-06
#  3.56984556e-06 1.45914796e-05 7.56069991e-07 1.87284381e-06
#  2.02689681e-06 1.87766874e-05 7.96089256e-06 3.42670712e-05
#  4.65826697e-05 1.21067629e-06 1.68224521e-06 7.70285860e-10
#  5.05644830e-05 1.50459759e-05 2.47639661e-05 1.69556230e-05
#  4.28164690e-05 1.28687117e-04 3.16907877e-05 3.28915313e-05
#  6.81018968e-05 4.62920409e-06 9.03005561e-06 1.47432795e-05
#  9.57682524e-06 1.42217706e-06 2.41436147e-05 1.64896026e-05
#  1.97384136e-06 5.27774168e-05 2.24728821e-06 1.61289409e-10
#  5.99463614e-05 2.65683570e-05 7.63184290e-06 1.27074326e-04
#  1.33777368e-05 7.30064192e-05 1.41128776e-06 4.74649478e-05
#  3.26491148e-05 1.55035394e-06 1.48194116e-04 1.60598802e-09
#  8.43375995e-06 5.08429477e-05 2.26994385e-04 1.28143041e-04
#  1.01116757e-03 1.23639989e-05 5.05387002e-03 2.85018322e-04
#  1.00726215e-06 4.98140895e-05 6.96928879e-05 3.26379396e-05
#  2.36928481e-05 7.44347901e-05 4.37012591e-05 4.71006749e-05
#  3.60618504e-06 7.02502264e-05 1.48436398e-04 3.35221220e-06
#  7.88236967e-05 7.72645674e-05 5.94642245e-05 7.36311085e-07
#  1.86581362e-13 1.08805148e-04 6.71037794e-06 1.66662860e-04
#  4.48525320e-05 1.33885923e-06 3.87250653e-04 5.08081545e-04
#  1.14373912e-02 1.90243082e-04 1.61991444e-03 9.37040073e-04
#  1.82946629e-03 1.82735465e-03 2.59486878e-04 2.03883273e-05
#  3.79687420e-03 1.37986027e-03]
